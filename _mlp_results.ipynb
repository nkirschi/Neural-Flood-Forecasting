# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np
import pandas as pd

# %%
mlp_results = pd.read_csv("/scratch/kirschstein/runs/mlp/results.csv", index_col=0)

def extract_results():
    return mlp_results.loc[[f"MLP_{fold}" for fold in range(3)]]

def print_table():
    display(pd.DataFrame(
        [
            ["{:.2f}%".format(100 * extract_results().mean(1).mean())
                    + " ± {:.2f}%".format(100 * extract_results().mean(1).std())
            ]
        ], 
        columns = [""],
        index = [""]
    ))

# %%
print_table()
# Out:
#
#   85.25% ± 1.63%
